# %% [markdown]
# 15 - Para cada elemento do array da questão anterior, calcule:
#
# * O seno
# * O cosseno
# * O log na base 10
# * O valor arredondado para inteiro

# %%
import math
import numpy as np
from random import randint

Q5 = np.random.rand(40)
Q6 = Q5 * 12
seno = np.sin(Q6)
cosseno = np.cos(Q6)
log = np.log10(Q6)
inteiro = np.round(Q6)

print('SENO...')
print(seno)
print('-'*100)

print('COSSENO...')
print(cosseno)
print('-'*100)

print('LOG...')
print(log)
print('-'*100)

print('INTEIRO...')
print(inteiro)
print('-'*100)
# Out:
# SENO...
# [ 0.11417302  0.10082899  0.56346704 -0.40883497 -0.72474012  0.17855289
#   0.96364431  0.98167092  0.55984071 -0.0548879   0.09615628  0.57556071
#   0.96720311 -0.98690048 -0.8078842  -0.80642008 -0.91597377  0.96530053
#   0.32927971  0.9079058  -0.61185122 -0.86356016  0.99408472  0.72413091
#   0.42221174 -0.98717848  0.79507271  0.6935981  -0.22660586  0.48859415
#   0.00691699 -0.98802887 -0.97321123  0.43668108  0.72995731 -0.19250996
#  -0.16658062 -0.96367444  0.95205969 -0.37692933]
# ----------------------------------------------------------------------------------------------------
# COSSENO...
# [-0.99346088  0.99490377  0.82613854  0.91260833 -0.68902232 -0.98393032
#  -0.2671884   0.19058383 -0.82860025 -0.99849252  0.99536625  0.81775905
#   0.25400421  0.16133022 -0.58934126  0.59134309  0.40123814  0.2611415
#  -0.94423243  0.41917426  0.79097287  0.50424582  0.10860738 -0.68966254
#   0.90649724 -0.15962032  0.60651413 -0.72036218  0.97398654 -0.87251118
#  -0.99997608  0.15426908  0.22991282 -0.89961638 -0.68349274  0.98129502
#  -0.98602784 -0.2670797  -0.30591232  0.92624202]
# ----------------------------------------------------------------------------------------------------
# LOG...
# [ 0.48103683 -0.99567594  0.83769964  0.76804642  1.01010631  0.96591924
#   0.2651176   0.88435489  0.40609699  0.50467582  0.80478599 -0.21233436
#   0.88065148  0.6879236   1.01558318  0.72795683  0.70971566  0.88022902
#   0.44809572  0.05624174  1.07583779  1.06160637  0.16493974  0.36769489
#   0.82730911  1.03483967  0.85747198  0.93743293  0.78208501  0.95008726
#   0.97395227  0.68728603  0.69411159  0.95293147  0.93482751  0.78457921
#   0.51969066  0.64758125  0.27454874  0.77060951]
# ----------------------------------------------------------------------------------------------------
# INTEIRO...
# [ 3.  0.  7.  6. 10.  9.  2.  8.  3.  3.  6.  1.  8.  5. 10.  5.  5.  8.
#   3.  1. 12. 12.  1.  2.  7. 11.  7.  9.  6.  9.  9.  5.  5.  9.  9.  6.
#   3.  4.  2.  6.]
# ----------------------------------------------------------------------------------------------------
