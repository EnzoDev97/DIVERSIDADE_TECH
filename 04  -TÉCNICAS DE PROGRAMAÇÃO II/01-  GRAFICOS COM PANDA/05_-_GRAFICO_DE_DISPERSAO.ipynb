# %% [markdown]
# #### Gráfico de Dispersão
# * Visão de comparação entre duas variáveis
# * Indica o quantos uma variável pode ou não influenciar a outra
# * Exemplo: Tempo de profissão e salário

# %%
# importando a biblioteca
import pandas as pd
import numpy as np
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# importando algumas bases de dados
peng = sns.load_dataset('penguins')

# %%
# verificando os dados novamente
peng.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# comparando o tamanho e altura do bico do pinguim
peng.plot.scatter(x='bill_length_mm', y='bill_depth_mm')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
# aplicando um filtro
peng[peng['species'] == 'Adelie'].head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# comparando o tamanho e altura do bico do pinguim com filtro
peng[peng['species'] == 'Adelie'].plot.scatter(x='bill_length_mm', y='bill_depth_mm')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
# comparando o tamanho e altura do bico do pinguim com outro filtro
peng[peng['sex'] == 'Male'].plot.scatter(x='bill_length_mm', y='bill_depth_mm')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
peng[peng['sex'] == 'Female'].plot.scatter(x='bill_length_mm', y='bill_depth_mm', color='yellow')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
# juntando os dois gráficos
# comparando o tamanho e altura do bico do pinguim com outro filtro
peng[peng['sex'] == 'Male'].plot.scatter(x='bill_length_mm', y='bill_depth_mm')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
# juntando os dois gráficos
# comparando o tamanho e altura do bico do pinguim com outro filtro
g1 = peng[peng['sex'] == 'Male'].plot.scatter(x='bill_length_mm', y='bill_depth_mm', color='purple')
g2 = peng[peng['sex'] == 'Female'].plot.scatter(x='bill_length_mm', y='bill_depth_mm', color='orange')

# %%
g1 = peng[peng['sex'] == 'Male'] \
      .plot.scatter(x='bill_length_mm', y='bill_depth_mm', color='purple')
g2 = peng[peng['sex'] == 'Female'] \
      .plot.scatter(x='bill_length_mm', y='bill_depth_mm', color='orange', ax=g1)
