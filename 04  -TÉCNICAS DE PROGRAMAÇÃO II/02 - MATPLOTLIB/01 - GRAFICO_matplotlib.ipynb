# %% [markdown]
# # 01 - Chamada do gráfico no matplotlib

# %%
import matplotlib.pyplot as plt

a = [1, 2, 3, 4, 5 ,6]
b = [10, 5, 3, 4, 6, 8]
plt.plot(a, b) # Chamada do gráfico no matplotlib
plt.show() # Retira a mensagem ao mostrar o gráfico. É o substituto do ; ao final da linha de comando
