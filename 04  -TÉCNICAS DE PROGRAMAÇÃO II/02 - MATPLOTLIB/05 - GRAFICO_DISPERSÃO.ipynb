# %%
import matplotlib.pyplot as plt
import random
import numpy as np


x = np.random.rand(10)
y = np.random.rand(10)
color = [1, 1, 2, 2, 2, 2, 3, 4, 1, 4]

plt.scatter(x=x, y=y, c=color)
plt.show()
