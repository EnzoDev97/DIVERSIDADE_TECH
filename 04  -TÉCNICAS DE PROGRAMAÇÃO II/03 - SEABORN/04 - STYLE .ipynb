# %% [markdown]
# ###  04 - APLICANDO A FUNÇÃO STYLE  QUE ALTERA O ESTILO DOS MARCADORES

# %%
import seaborn as sns 
x = [1, 2, 3, 4, 5 ,6]
y = [10, 5, 3, 4, 6, 8]
z = ['a', 'b', 'c', 'c', 'a', 'a']
sns.scatterplot(x=x, y=y, style=z); # Altera o estilo do marcador baseado na categoria
