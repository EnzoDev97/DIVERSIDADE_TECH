# %% [markdown]
# ###  08 - GRÁFICO LINHA

# %%
import seaborn as sns
import numpy as np
import pandas as pd

x = [1, 2, 3, 4, 5 ,6]
y = [10, 5, 3, 4, 6, 8]

sns.lineplot(x=x, y=y);

# %%
sns.lineplot(x='sepal length (cm)', y='petal length (cm)', data=df);
