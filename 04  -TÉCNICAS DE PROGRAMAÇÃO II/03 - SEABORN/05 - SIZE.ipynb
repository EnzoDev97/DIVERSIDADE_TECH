# %% [markdown]
# ### 05 - APLIQUE A FUNÇÃO SIZE PARA ALTERAR O TAMANHO

# %%
import seaborn as sns
x = [1, 2, 3, 4, 5 ,6]
y = [10, 5, 3, 4, 6, 8]
z = [10, 15, 12, 14, 18, 21]
sns.scatterplot(x=x, y=y, size=z); # Indica o tamanho do marcador baseado no valor proveniente da lista
